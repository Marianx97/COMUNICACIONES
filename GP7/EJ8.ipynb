# %% [markdown]
# # Ejercicio 8
#
# ![consigna](img/ej8_consigna.JPG)

# %% [markdown]
# $\displaystyle Att = 100dB$
#
# $\displaystyle \eta = 2,54x10^{18} \frac{W}{Hz}$
#
# $\displaystyle B_{eq} = 1,1 B$
#
# $\displaystyle {SNR}_d = 40dB = 10000$
#
# $\displaystyle M=128 \to l = 7$
#
# $\displaystyle FC = \sqrt{3}$
#
# $\displaystyle B_{m_1} = 3KHz \to F_{s_1} = 6KHz \to R=42KHz \to T_b = \frac{1}{R} = 23,809{\mu}s$
#
# $\displaystyle B_{m_2} = 5KHz \to F_{s_2} = 10KHz \to R=70KHz \to T_b = \frac{1}{R} = 14,286{\mu}s$
#
# $\displaystyle 10000 = \frac{3.128^2.\left(\frac{1}{\sqrt{3}}\right)^2}{1+4.P_e.(128^2-1)} = \frac{16384}{1+65532.P_e} \to P_e = 9,7416x10^{-6} \to k\approx 4,3$
#
# $\displaystyle P_{s_{(t)}} = Att + \langle(S_{s_{(t)}})^2\rangle $
#
# Para Unipolar:
#
# $\displaystyle \langle(S_{s_{(t)}})^2\rangle = \frac{A^2}{2}$
#
# Para Polar:
#
# $\displaystyle \langle(S_{s_{(t)}})^2\rangle = \frac{(2.A)^2}{2} = 2.A^2$
#
# $\displaystyle K_{unipolar{\:}NRZ} = \sqrt{\frac{A^2}{R.N_0}} \to A = \sqrt{K^2.R.N_0} = \left\{\begin{array}{cc}
# \sqrt{1,972x10^{-12}} = 1,4044{\mu}V \\
# \sqrt{3,287x10^{-12}} = 1,8131{\mu}V
# \end{array}\right\}$
#
# $\displaystyle K_{polar{\:}NRZ} = \frac{2}{3}.\sqrt{\frac{2.A^2}{R.N_0}} \to A = \sqrt{\frac{9}{8}.K^2.R.N_0} = \left\{\begin{array}{cc}
# \sqrt{2,2191x10^{-12}} = 1,4896{\mu}V \\
# \sqrt{3,6984x10^{-12}} = 1,9231{\mu}V
# \end{array}\right\}$
#
# $\displaystyle K_{OOK} = \sqrt{\frac{A^2}{4.R.N_0}} \to A = \sqrt{4.K^2.R.N_0} = \left\{\begin{array}{cc}
# \sqrt{7,89x10^{-12}} = 2,8089{\mu}V \\
# \sqrt{1,315x10^{-11}} = 3,6263{\mu}V
# \end{array}\right\}$
#
# $\displaystyle K_{BPSK} = \sqrt{\frac{A^2}{R.N_0}} \to A = \sqrt{K^2.R.N_0} = \left\{\begin{array}{cc}
# \sqrt{1,972x10^{-12}} = 1,4044{\mu}V \\
# \sqrt{3,287x10^{-12}} = 1,8131{\mu}V
# \end{array}\right\}$
#
# $\displaystyle K_{BFSK} = \sqrt{\frac{A^2}{2.R.N_0}} \to A = \sqrt{2.K^2.R.N_0} = \left\{\begin{array}{cc}
# \sqrt{3,945x10^{-12}} = 1,9862{\mu}V \\
# \sqrt{6,575x10^{-12}} = 2,5642{\mu}V
# \end{array}\right\}$
#
#
#
# $\displaystyle {S_{s_{(t)}}}_{unipolar{\:}NRZ} = \frac{A^2}{2} = \left\{\begin{array}{cc}
# \sqrt{0,986x10^{-12}W} = -120,06dB \\
# \sqrt{1,6435x10^{-12}W} = -117,84dB
# \end{array}\right\}$
#
# $\displaystyle {S_{s_{(t)}}}_{polar{\:}NRZ} = 2.A^2 = \left\{\begin{array}{cc}
# \sqrt{4,4382x10^{-12}W} = -113,53dB \\
# \sqrt{7,3968x10^{-12}W} = -111,31dB
# \end{array}\right\}$
#
# $\displaystyle {S_{s_{(t)}}}_{OOK} = \frac{A^2}{2} = \left\{\begin{array}{cc}
# \sqrt{3,945x10^{-12}W} = -114,04dB \\
# \sqrt{6,575x10^{-12}W} = -111,82dB
# \end{array}\right\}$
#
# $\displaystyle {S_{s_{(t)}}}_{BPSK} = \frac{A^2}{2} = \left\{\begin{array}{cc}
# \sqrt{0,98625x10^{-12}W} = -120,06dB \\
# \sqrt{1,6475x10^{-12}W} = -117,84dB
# \end{array}\right\}$
#
# $\displaystyle {S_{s_{(t)}}}_{BFSK} = \frac{A^2}{2} = \left\{\begin{array}{cc}
# \sqrt{1,9725x10^{-12}W} = -117,05dB \\
# \sqrt{3,2875x10^{-12}W} = 114,83dB
# \end{array}\right\}$

# %% [markdown]
# ## Resultados
#
# ![resultados](img/ej8_resultados.JPG)
